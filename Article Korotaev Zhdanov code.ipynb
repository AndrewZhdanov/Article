# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from io import BytesIO
import tarfile
from urllib.request import urlopen

# %%
df=pd.read_excel('democracy.xlsx')
df
# Out:
#     Unnamed: 0  Polity V     FH   EIU
# 0         2009       NaN    NaN  8.20
# 1         2010       NaN    NaN  8.18
# 2         2011       NaN    NaN  8.11
# 3         2012       NaN    NaN  8.11
# 4         2013       NaN    NaN  8.11
# 5         2014      10.0  100.0  8.11
# 6         2015      10.0  100.0  8.05
# 7         2016       8.0   90.0  7.98
# 8         2017       8.0   89.0  7.98
# 9         2018       8.0   86.0  7.96
# 10        2019       7.0   86.0  7.96
# 11        2020       5.0   86.0  7.92
# 12        2021       NaN   83.0   NaN

# %%
import random

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import pylab


plt.style.use('ggplot')

# %%
def add_titlebox(ax, text):
    ax.text(.79, .8, text,
        horizontalalignment='center',
        transform=ax.transAxes,
        bbox=dict(facecolor='white', alpha=0.6),
        fontsize=12.5)
    return ax

def add_titlebox2(ax, text):
    ax.text(.82, .8, text,
        horizontalalignment='center',
        transform=ax.transAxes,
        bbox=dict(facecolor='white', alpha=0.6),
        fontsize=12.5)
    return ax

def add_titlebox1(ax, text):
    ax.text(.18, .07, text,
        horizontalalignment='center',
        transform=ax.transAxes,
        bbox=dict(facecolor='white', alpha=0.6),
        fontsize=18)
    return ax

# %%
gridsize = (3, 2)
fig = plt.figure(figsize=(20, 10))
ax1 = plt.subplot2grid(gridsize, (0, 0), colspan=2, rowspan=2)
ax2 = plt.subplot2grid(gridsize, (2, 0))
ax3 = plt.subplot2grid(gridsize, (2, 1))


ax1.set_title(
    'Dynamics of indicators of the level of democracy in the United States',
    fontsize=24
)
 
ax1.plot(df['Unnamed: 0'], df['EIU'], color='#000000')
ax2.plot(df['Unnamed: 0'], df['Polity V'], color='#000000')
ax3.plot(df['Unnamed: 0'], df['FH'], color='#000000')

ax1.axvline(linewidth=4, color='#949494', linestyle = '--', x=2013, ymin=0, ymax=1)
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=2012, ymin=0.5, ymax=0.55)
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=2014, ymin=0.5, ymax=0.55)
ax1.hlines(8.067, 2012, 2014, linewidth=2, color='r', linestyle = '-')

ax1.axvline(linewidth=4, color='#949494', linestyle = '--', x=2018, ymin=0, ymax=1)
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=2016, ymin=0.5, ymax=0.55)
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=2019, ymin=0.5, ymax=0.55)
ax1.hlines(8.067, 2016, 2019, linewidth=2, color='r', linestyle = '-')

ax2.axvline(linewidth=3, color='#949494', linestyle = '--', x=2018, ymin=0, ymax=1)
ax2.axvline(linewidth=2, color='r', linestyle = '-', x=2017, ymin=0.3, ymax=0.35)
ax2.axvline(linewidth=2, color='r', linestyle = '-', x=2019, ymin=0.3, ymax=0.35)
ax2.hlines(6.56, 2017, 2019, linewidth=2, color='r', linestyle = '-')

ax3.axvline(linewidth=3, color='#949494', linestyle = '--', x=2018, ymin=0, ymax=1)
ax3.axvline(linewidth=2, color='r', linestyle = '-', x=2017, ymin=0.5, ymax=0.55)
ax3.axvline(linewidth=2, color='r', linestyle = '-', x=2019, ymin=0.5, ymax=0.55)
ax3.hlines(92, 2017, 2019, linewidth=2, color='r', linestyle = '-')


add_titlebox2(ax2, 'Polity V Index')
add_titlebox(ax3, 'Freedom House Index')
add_titlebox1(ax1,'Economist Intelligence Unit Index')

plt.show()

ax2.set_facecolor('#f9f9f9')
ax2.grid('#838383')

# %%
df=pd.read_excel('polarization.xls')
df
# Out:
#      Year  Polarization of society  Polarization of society CI (Low)  \
# 0    1900                      NaN                               NaN
# 1    1901                      NaN                               NaN
# 2    1902                      NaN                               NaN
# 3    1903                      NaN                               NaN
# 4    1904                      NaN                               NaN
# ..    ...                      ...                               ...
# 116  2016                    1.346                             1.101
# 117  2017                    1.346                             1.101
# 118  2018                    1.364                             1.146
# 119  2019                    1.364                             1.146
# 120  2020                    1.364                             1.146
#
#      Polarization of society CI (High)  Political polarization  \
# 0                                  NaN                   1.211
# ...

# %%
def add_titlebox(ax, text):
    ax.text(.467, .18, text,
        horizontalalignment='center',
        transform=ax.transAxes,
        bbox=dict(facecolor='white', alpha=0.6),
        fontsize=12.5)
    return ax

def add_titlebox2(ax, text):
    ax.text(.78, .18, text,
        horizontalalignment='center',
        transform=ax.transAxes,
        bbox=dict(facecolor='white', alpha=0.6),
        fontsize=12.5)
    return ax

def add_titlebox1(ax, text):
    ax.text(.15, .87, text,
        horizontalalignment='center',
        transform=ax.transAxes,
        bbox=dict(facecolor='white', alpha=0.6),
        fontsize=20)
    return ax

# %%
import pylab
plt.style.use('ggplot') 

gridsize = (3, 2)
fig = plt.figure(figsize=(20, 10))
ax1 = plt.subplot2grid(gridsize, (0, 0), colspan=2, rowspan=2)
ax2 = plt.subplot2grid(gridsize, (2, 0))
ax3 = plt.subplot2grid(gridsize, (2, 1))

ax1.set_title(
    'Dynamics of polarization indicators in the USA',
    fontsize=24
)
 
ax2.plot(df['Year'], df['Polarization of society'], color='#000000')
ax2.plot(df['Year'], df['Polarization of society CI (Low)'], color='#000000', linestyle = '--', linewidth=0.7)
ax2.plot(df['Year'], df['Polarization of society CI (High)'], color='#000000', linestyle = '--',  linewidth=0.7)


ax1.plot(df['Year'], df['Political polarization'], color='#000000')
ax1.plot(df['Year'], df['Political polarization CI (Low)'], color='#000000', linestyle = '--', linewidth=0.7)
ax1.plot(df['Year'], df['Political polarization CI (High)'], color='#000000', linestyle = '--',  linewidth=0.7)

ax3.plot(df['Year'], df['negative_between_party'], color='#000000')


ax2.axvline(linewidth=4, color='#949494', linestyle = '--', x=2003, ymin=0, ymax=1)
ax2.axvline(linewidth=4, color='#949494', linestyle = '--', x=2006, ymin=0, ymax=1)
ax2.axvline(linewidth=4, color='#949494', linestyle = '--', x=2010, ymin=0, ymax=1) 
ax2.axvline(linewidth=2, color='r', linestyle = '-', x=2002, ymin=0.5, ymax=0.55)
ax2.axvline(linewidth=2, color='r', linestyle = '-', x=2004, ymin=0.5, ymax=0.55)
ax2.hlines(0.9, 2002, 2004, linewidth=2, color='r', linestyle = '-')

ax1.axvline(linewidth=4, color='#949494', linestyle = '--', x=1982, ymin=0, ymax=1) 
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=1978, ymin=0.5, ymax=0.55)
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=1985, ymin=0.5, ymax=0.55)
ax1.hlines(2.38, 1978, 1985, linewidth=2, color='r', linestyle = '-')
ax1.axvline(linewidth=4, color='#949494', linestyle = '--', x=2002, ymin=0, ymax=1) 
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=2003, ymin=0.5, ymax=0.55)
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=2000, ymin=0.5, ymax=0.55)
ax1.hlines(2.38, 2000, 2003, linewidth=2, color='r', linestyle = '-')

ax3.axvline(linewidth=4, color='#949494', linestyle = '--', x=1993, ymin=0, ymax=1)
ax3.axvline(linewidth=4, color='#949494', linestyle = '--', x=2012, ymin=0, ymax=1)
ax3.axvline(linewidth=2, color='r', linestyle = '-', x=1990, ymin=0.5, ymax=0.55)
ax3.axvline(linewidth=2, color='r', linestyle = '-', x=1994, ymin=0.5, ymax=0.55)
ax3.hlines(0.807, 1990, 1994, linewidth=2, color='r', linestyle = '-')

ax3.axvline(linewidth=2, color='r', linestyle = '-', x=2011, ymin=0.5, ymax=0.55)
ax3.axvline(linewidth=2, color='r', linestyle = '-', x=2014, ymin=0.5, ymax=0.55)
ax3.hlines(0.807, 2011, 2014, linewidth=2, color='r', linestyle = '-')

add_titlebox2(ax2, 'Polarization of society (V-Dem)')
add_titlebox(ax3, 'Polarization in the U.S. Congress (Neal, 2020)')
add_titlebox1(ax1,'Political polarization (V-Dem)')

# %%
df=pd.read_excel('corruption.xlsx')
df
# Out:
#     year  CPI  Control of corruption
# 0   1997  NaN                   1.57
# 1   1998  7.5                   1.60
# 2   1999  7.5                   1.60
# 3   2000  7.8                   1.60
# 4   2001  7.6                   1.66
# 5   2002  7.7                   1.92
# 6   2003  7.5                   1.76
# 7   2004  7.5                   1.83
# 8   2005  7.6                   1.55
# 9   2006  7.3                   1.35
# 10  2007  7.2                   1.39
# 11  2008  7.3                   1.45
# 12  2009  7.5                   1.29
# 13  2010  7.1                   1.27
# 14  2011  7.1                   1.27
# 15  2012  7.3                   1.41
# 16  2013  7.3                   1.31
# 17  2014  7.4                   1.38
# 18  2015  7.6                   1.40
# 19  2016  7.4                   1.37
# 20  2017  7.5                   1.38
# 21  2018  7.1                   1.33
# 22  2019  6.9                   1.22
# 23  2020  6.7                    NaN

# %%
def add_titlebox1(ax, text):
    ax.text(.83, .87, text,
        horizontalalignment='center',
        transform=ax.transAxes,
        bbox=dict(facecolor='white', alpha=0.6),
        fontsize=15)
    return ax

# %%
gridsize = (4, 2)

import pylab
plt.style.use('ggplot') 

fig = plt.figure(figsize=(15, 9))
ax1 = plt.subplot2grid(gridsize, (0, 0), colspan=2, rowspan=2)
ax2 = plt.subplot2grid(gridsize, (2, 0), colspan=2, rowspan=2)

ax1.set_title(
    'Trends in US Corruption Indicators',
    fontsize=24
)

ax1.plot(df['year'], df['CPI'], color='#000000')
ax2.plot(df['year'], df['Control of corruption'], color='#000000')

ax1.axvline(linewidth=4, color='#949494', linestyle = '--', x=2005, ymin=0, ymax=1) 
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=2003, ymin=0.5, ymax=0.55)
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=2007, ymin=0.5, ymax=0.55)
ax1.hlines(7.28, 2003, 2007, linewidth=2, color='r', linestyle = '-')

ax1.axvline(linewidth=4, color='#949494', linestyle = '--', x=2013, ymin=0, ymax=1) 
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=2011, ymin=0.5, ymax=0.55)
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=2016, ymin=0.5, ymax=0.55)
ax1.hlines(7.28, 2011, 2016, linewidth=2, color='r', linestyle = '-')

ax2.axvline(linewidth=4, color='#949494', linestyle = '--', x=2001, ymin=0, ymax=1) 
ax2.axvline(linewidth=2, color='r', linestyle = '-', x=1998, ymin=0.55, ymax=0.6)
ax2.axvline(linewidth=2, color='r', linestyle = '-', x=2002, ymin=0.55, ymax=0.6)
ax2.hlines(1.63, 1998, 2002, linewidth=2, color='r', linestyle = '-')

ax2.axvline(linewidth=4, color='#949494', linestyle = '--', x=2004, ymin=0, ymax=1) 
ax2.axvline(linewidth=2, color='r', linestyle = '-', x=2003, ymin=0.55, ymax=0.6)
ax2.axvline(linewidth=2, color='r', linestyle = '-', x=2005, ymin=0.55, ymax=0.6)
ax2.hlines(1.63, 2003, 2005, linewidth=2, color='r', linestyle = '-')

ax2.axvline(linewidth=4, color='#949494', linestyle = '--', x=2008, ymin=0, ymax=1) 
ax2.axvline(linewidth=2, color='r', linestyle = '-', x=2005, ymin=0.55, ymax=0.6)
ax2.axvline(linewidth=2, color='r', linestyle = '-', x=2014, ymin=0.55, ymax=0.6)
ax2.hlines(1.63, 2005, 2014, linewidth=2, color='r', linestyle = '-')

add_titlebox1(ax1,'Corruption Perceptions Index')
add_titlebox1(ax2, 'Control of corruption (WGI)')

# %%
df=pd.read_csv('_Western Europe.csv')
df2=pd.read_csv('United States of America (1).csv')
df2
# Out:
#      Year  Legislature corrupt activities  \
# 0    1900                           2.678
# 1    1901                           2.678
# 2    1902                           2.678
# 3    1903                           2.678
# 4    1904                           2.678
# ..    ...                             ...
# 116  2016                           2.646
# 117  2017                           2.704
# 118  2018                           2.704
# 119  2019                           2.704
# 120  2020                           2.704
#
#      Legislature corrupt activities CI (Low)  \
# 0                                      2.416
# 1                                      2.416
# 2                                      2.416
# 3                                      2.416
# 4                                      2.416
# ..                                       ...
# 116                                    2.417
# 117                                    2.450
# ...

# %%
fig = plt.figure(figsize=(18, 12))
ax1 = plt.subplot2grid(gridsize, (0, 0), colspan=2, rowspan=2)

ax1.set_title(
    'Dynamics of corruption indicators in the USA and Western Europe',
    fontsize=18
)

ax1.plot(df['Year'], df['Legislature corrupt activities'], color='#000000', label = 'Legislature corrupt activities in Western Europe')
ax1.plot(df['Year'], df['Legislature corrupt activities CI (Low)'], color='#a6a6a6', linestyle = '--')
ax1.plot(df['Year'], df['Legislature corrupt activities CI (High)'], color='#a6a6a6', linestyle = '--')

ax1.plot(df2['Year'], df2['Legislature corrupt activities'], color='#000000', linestyle = ':', linewidth=2, label = 'Legislature corrupt activities in the USA')
ax1.plot(df2['Year'], df2['Legislature corrupt activities CI (Low)'], color='#a6a6a6', linestyle = '--')
ax1.plot(df2['Year'], df2['Legislature corrupt activities CI (High)'], color='#a6a6a6', linestyle = '--')

plt.legend(fontsize=16)

# %%
df=pd.read_excel('effectiviness.xls')
df
# Out:
#     Year  Government effectiveness  Voice and Accontability
# 0   1996                     1.525                     1.35
# 1   1997                     1.525                     1.35
# 2   1998                     1.765                     1.34
# 3   1999                     1.765                     1.34
# 4   2000                     1.803                     1.31
# 5   2001                     1.803                     1.31
# 6   2002                     1.680                     1.34
# 7   2003                     1.603                     1.34
# 8   2004                     1.762                     1.33
# 9   2005                     1.536                     1.29
# 10  2006                     1.586                     1.10
# 11  2007                     1.650                     1.11
# 12  2008                     1.614                     1.14
# 13  2009                     1.507                     1.10
# 14  2010                     1.558                     1.13
# ...

# %%
def add_titlebox1(ax, text):
    ax.text(.83, .87, text,
        horizontalalignment='center',
        transform=ax.transAxes,
        bbox=dict(facecolor='white', alpha=0.6),
        fontsize=15)
    return ax

# %%
gridsize = (4, 2)

fig = plt.figure(figsize=(15, 9))
ax1 = plt.subplot2grid(gridsize, (0, 0), colspan=2, rowspan=2)
ax2 = plt.subplot2grid(gridsize, (2, 0), colspan=2, rowspan=2)

ax1.set_title(
    'Dynamics of indicators of the effectiveness of the political system in the United States',
    fontsize=18
)

ax1.plot(df['Year'], df['Government effectiveness'], color='#000000')
ax2.plot(df['Year'], df['Voice and Accontability'], color='#000000')

ax1.axvline(linewidth=4, color='#949494', linestyle = '--', x=2004, ymin=0, ymax=1) 
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=2003, ymin=0.5, ymax=0.55)
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=2007, ymin=0.5, ymax=0.55)
ax1.hlines(1.64, 2003, 2007, linewidth=2, color='r', linestyle = '-')

ax2.axvline(linewidth=4, color='#949494', linestyle = '--', x=2005, ymin=0, ymax=1) 
ax2.axvline(linewidth=2, color='r', linestyle = '-', x=2004, ymin=0.55, ymax=0.6)
ax2.axvline(linewidth=2, color='r', linestyle = '-', x=2006, ymin=0.55, ymax=0.6)
ax2.hlines(1.19, 2004, 2006, linewidth=2, color='r', linestyle = '-')

ax2.axvline(linewidth=4, color='#949494', linestyle = '--', x=2016, ymin=0, ymax=1) 
ax2.axvline(linewidth=2, color='r', linestyle = '-', x=2013, ymin=0.55, ymax=0.6)
ax2.axvline(linewidth=2, color='r', linestyle = '-', x=2017, ymin=0.55, ymax=0.6)
ax2.hlines(1.19, 2013, 2017, linewidth=2, color='r', linestyle = '-')

add_titlebox1(ax1,'Government effectiveness')
add_titlebox1(ax2, 'Voice and Accontability')

# %%
df=pd.read_excel('unequality.xlsx')
df
# Out:
#      Year  income50  income1
# 0    1913    0.1473   0.2052
# 1    1914    0.1456   0.2101
# 2    1915    0.1477   0.2037
# 3    1916    0.1436   0.2146
# 4    1917    0.1426   0.2139
# ..    ...       ...      ...
# 102  2015    0.1289   0.1888
# 103  2016    0.1283   0.1863
# 104  2017    0.1334   0.1880
# 105  2018    0.1326   0.1896
# 106  2019    0.1331   0.1876
#
# [107 rows x 3 columns]

# %%
fig = plt.figure(figsize=(18, 12))
ax1 = plt.subplot2grid(gridsize, (0, 0), colspan=2, rowspan=2)

ax1.set_title(
    'Trends in inequality indicators in the United States',
    fontsize=18
)

ax1.plot(df['Year'], df['income50'], color='#000000', label = 'Pre-tax national income (bottom 50%)')

ax1.axvline(linewidth=4, color='#949494', linestyle = '--', x=1985, ymin=0, ymax=1) 
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=1982, ymin=0.5, ymax=0.55)
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=1986, ymin=0.5, ymax=0.55)
ax1.hlines(0.167, 1982, 1986, linewidth=2, color='r', linestyle = '-')

ax1.axvline(linewidth=4, color='#949494', linestyle = '--', x=2002, ymin=0, ymax=1) 
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=2001, ymin=0.5, ymax=0.55)
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=2004, ymin=0.5, ymax=0.55)
ax1.hlines(0.167, 2001, 2004, linewidth=2, color='r', linestyle = '-')

ax1.plot(df['Year'], df['income1'], color='#000000', linestyle = '--', label = 'Pre-tax national income (top 1%)')


plt.legend(fontsize=16)

# %%
df=pd.read_excel('culture.xlsx')
df
# Out:
#     year  dembad    instbad
# 0   1990     9.0  24.666667
# 1   1991     9.0  24.666667
# 2   1992     9.0  33.000000
# 3   1993     9.0  36.000000
# 4   1994     9.0  34.666667
# 5   1995     9.0  32.666667
# 6   1996     9.0  33.666667
# 7   1997     9.0  30.333333
# 8   1998     9.0  26.333333
# 9   1999     9.0  28.333333
# 10  2000    10.5  32.333333
# 11  2001    10.5  28.666667
# 12  2002    10.5  23.333333
# 13  2003    10.5  25.000000
# 14  2004    10.5  27.333333
# 15  2005    13.7  32.333333
# 16  2006    13.7  37.333333
# 17  2007    13.7  43.000000
# 18  2008    13.7  41.666667
# 19  2009    13.7  33.000000
# 20  2010    17.1  41.666667
# 21  2011    17.1  42.666667
# 22  2012    17.1  44.333333
# 23  2013    17.1  44.000000
# 24  2014    17.1  48.666667
# 25  2015    14.2  46.666667
# 26  2016    14.2  46.000000
# 27  2017    14.2  42.000000
# 28  2018    14.2  41.333333
# 29  2019    14.2  42.666667
# 30  2020    14.2  39.333333

# %%
fig = plt.figure(figsize=(18, 12))
ax1 = plt.subplot2grid(gridsize, (0, 0), colspan=2, rowspan=2)

ax1.set_title(
    'Dynamics of disapproval of democracy in the USA (in %)',
    fontsize=18
)

ax1.plot(df['year'], df['dembad'], color='#000000', label = 'Pre-tax national income (bottom 50%)')

# %%
fig = plt.figure(figsize=(18, 12))
ax1 = plt.subplot2grid(gridsize, (0, 0), colspan=2, rowspan=2)

ax1.set_title(
    'Dynamics of disapproval of political institutions in the USA (in %)',
    fontsize=18
)

ax1.plot(df['year'], df['instbad'], color='#000000', label = 'Pre-tax national income (bottom 50%)')

ax1.axvline(linewidth=4, color='#949494', linestyle = '--', x=2006, ymin=0, ymax=1) 
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=2005, ymin=0.5, ymax=0.55)
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=2007, ymin=0.5, ymax=0.55)
ax1.hlines(36.7, 2005, 2007, linewidth=2, color='r', linestyle = '-')

# %%
df=pd.read_excel('radicals.xlsx')
df
# Out:
#     year  violence   rad  violencelow  violencehigh
# 0   1990     1.168  22.5        0.569         1.810
# 1   1991     1.168  23.0        0.569         1.810
# 2   1992     1.152  24.0        0.604         1.787
# 3   1993     1.152  25.0        0.604         1.787
# 4   1994     1.154  25.5        0.536         1.759
# 5   1995     1.154  26.0        0.536         1.759
# 6   1996     1.142  27.0        0.513         1.670
# 7   1997     1.142  28.0        0.513         1.670
# 8   1998     1.134  29.0        0.562         1.759
# 9   1999     1.134  30.0        0.562         1.759
# 10  2000     1.106  29.0        0.405         1.574
# 11  2001     1.106  28.0        0.405         1.574
# 12  2002     1.127  27.0        0.471         1.676
# 13  2003     1.127  26.0        0.471         1.676
# 14  2004     1.178  25.0        0.588         1.791
# 15  2005     1.178  24.0        0.588         1.791
# 16  2006     1.333  25.0        0.795         1.805
# ...

# %%
fig = plt.figure(figsize=(18, 12))
ax1 = plt.subplot2grid(gridsize, (0, 0), colspan=2, rowspan=2)

ax1.set_title(
    'Dynamics of growth of radical sentiments in the USA (in %)',
    fontsize=18
)

ax1.plot(df['year'], df['rad'], color='#000000', label = 'Pre-tax national income (bottom 50%)')

ax1.axvline(linewidth=4, color='#949494', linestyle = '--', x=1994, ymin=0, ymax=1) 
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=1991, ymin=0.5, ymax=0.55)
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=1995, ymin=0.5, ymax=0.55)
ax1.hlines(34.7, 1991, 1995, linewidth=2, color='r', linestyle = '-')

ax1.axvline(linewidth=4, color='#949494', linestyle = '--', x=2005, ymin=0, ymax=1) 
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=1999, ymin=0.5, ymax=0.55)
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=2002, ymin=0.5, ymax=0.55)
ax1.hlines(34.7, 1999, 2002, linewidth=2, color='r', linestyle = '-')

ax1.axvline(linewidth=4, color='#949494', linestyle = '--', x=2001, ymin=0, ymax=1)

# %%
fig = plt.figure(figsize=(18, 12))
ax1 = plt.subplot2grid(gridsize, (0, 0), colspan=2, rowspan=2)

ax1.set_title(
    'Dynamics of preference for peaceful resolution of political conflicts in the United States',
    fontsize=18
)

ax1.plot(df['year'], df['violence'], color='#000000')
ax1.plot(df['year'], df['violencelow'], color='#a6a6a6', linestyle = '--')
ax1.plot(df['year'], df['violencehigh'], color='#a6a6a6', linestyle = '--')

ax1.axvline(linewidth=4, color='#949494', linestyle = '--', x=2015, ymin=0, ymax=1) 
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=2014, ymin=0.5, ymax=0.55)
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=2016, ymin=0.5, ymax=0.55)
ax1.hlines(1.15, 2014, 2016, linewidth=2, color='r', linestyle = '-')

ax1.axvline(linewidth=4, color='#949494', linestyle = '--', x=2005, ymin=0, ymax=1) 
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=2004, ymin=0.5, ymax=0.55)
ax1.axvline(linewidth=2, color='r', linestyle = '-', x=2006, ymin=0.5, ymax=0.55)
ax1.hlines(1.15, 2004, 2006, linewidth=2, color='r', linestyle = '-')

# %% [markdown]
# ## Regression analysis

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as statf

# %%
df=pd.read_excel('regression_data_article.xlsx')
df
# Out:
#     year   dem  Govef       CPI       Pol  unequality  dembad  institbad  \
# 0   1990  8.22    2.0  7.842291  0.775453       -0.02     9.0  24.666667
# 1   1991  8.22    1.9  7.817149  0.775492       -0.02     9.0  24.666667
# 2   1992  8.22    1.8  7.792007  0.775492       -0.01     9.0  33.000000
# 3   1993  8.22    1.7  7.766865  0.840440       -0.01     9.0  36.000000
# 4   1994  8.22    1.6  7.741723  0.840440       -0.01     9.0  34.666667
# 5   1995  8.22    1.6  7.790000  0.945504        0.00     9.0  32.666667
# 6   1996  8.22    1.5  7.660000  0.945504        0.01     9.0  33.666667
# 7   1997  8.22    1.5  7.610000  0.957432        0.02     9.0  30.333333
# 8   1998  8.22    1.7  7.500000  0.957432        0.02     9.0  26.333333
# 9   1999  8.22    1.7  7.500000  0.936147        0.03     9.0  28.333333
# 10  2000  8.22    1.8  7.800000  0.936147        0.03    10.5  32.333333
# 11  2001  8.22    1.7  7.600000  0.916276        0.02    10.5  28.666667
# ...

# %%
m1 = statf.ols(formula = 'Govef ~ Pol2', data = df).fit()
print(m1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Govef   R-squared:                       0.635
# Model:                            OLS   Adj. R-squared:                  0.622
# Method:                 Least Squares   F-statistic:                     50.45
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           8.15e-08
# Time:                        22:22:09   Log-Likelihood:                 31.810
# No. Observations:                  31   AIC:                            -59.62
# Df Residuals:                      29   BIC:                            -56.75
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9664      0.055     35.816      0.000       1.854       2.079
# ...

# %%
m2 = statf.ols(formula = 'Govef ~ Pol2 + Govef1', data = df).fit()
print(m2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Govef   R-squared:                       0.773
# Model:                            OLS   Adj. R-squared:                  0.756
# Method:                 Least Squares   F-statistic:                     45.88
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           2.06e-09
# Time:                        22:22:17   Log-Likelihood:                 42.059
# No. Observations:                  30   AIC:                            -78.12
# Df Residuals:                      27   BIC:                            -73.92
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9348      0.259      3.605      0.001       0.403       1.467
# ...

# %%
m3 = statf.ols(formula = 'Govef ~ Pol2 + Govef1 + Govef2', data = df).fit()
print(m3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Govef   R-squared:                       0.719
# Model:                            OLS   Adj. R-squared:                  0.686
# Method:                 Least Squares   F-statistic:                     21.34
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           4.50e-07
# Time:                        22:22:29   Log-Likelihood:                 40.824
# No. Observations:                  29   AIC:                            -73.65
# Df Residuals:                      25   BIC:                            -68.18
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.0997      0.312      3.522      0.002       0.457       1.743
# ...

# %%
m4= statf.ols(formula = 'Govef ~ CPI', data = df).fit()
print(m4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Govef   R-squared:                       0.515
# Model:                            OLS   Adj. R-squared:                  0.498
# Method:                 Least Squares   F-statistic:                     30.75
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           5.58e-06
# Time:                        22:40:05   Log-Likelihood:                 27.394
# No. Observations:                  31   AIC:                            -50.79
# Df Residuals:                      29   BIC:                            -47.92
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.1540      0.496     -2.328      0.027      -2.168      -0.140
# ...

# %%
m5= statf.ols(formula = 'Govef ~ CPI + Govef1', data = df).fit()
print(m5.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Govef   R-squared:                       0.756
# Model:                            OLS   Adj. R-squared:                  0.738
# Method:                 Least Squares   F-statistic:                     41.77
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           5.44e-09
# Time:                        22:40:10   Log-Likelihood:                 40.983
# No. Observations:                  30   AIC:                            -75.97
# Df Residuals:                      27   BIC:                            -71.76
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.2313      0.340     -0.679      0.503      -0.930       0.467
# ...

# %%
m6= statf.ols(formula = 'Govef ~ CPI + Govef1 + Govef2', data = df).fit()
print(m6.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Govef   R-squared:                       0.690
# Model:                            OLS   Adj. R-squared:                  0.653
# Method:                 Least Squares   F-statistic:                     18.58
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           1.50e-06
# Time:                        22:40:17   Log-Likelihood:                 39.408
# No. Observations:                  29   AIC:                            -70.82
# Df Residuals:                      25   BIC:                            -65.35
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.2158      0.360     -0.600      0.554      -0.956       0.525
# ...

# %%
m7= statf.ols(formula = 'dem ~ Pol2', data = df).fit()
print(m7.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    dem   R-squared:                       0.736
# Model:                            OLS   Adj. R-squared:                  0.727
# Method:                 Least Squares   F-statistic:                     80.71
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           7.08e-10
# Time:                        22:40:23   Log-Likelihood:                 48.811
# No. Observations:                  31   AIC:                            -93.62
# Df Residuals:                      29   BIC:                            -90.75
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      8.4289      0.032    265.681      0.000       8.364       8.494
# ...

# %%
m8= statf.ols(formula = 'dem ~ Pol2 + dem1', data = df).fit()
print(m8.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    dem   R-squared:                       0.967
# Model:                            OLS   Adj. R-squared:                  0.964
# Method:                 Least Squares   F-statistic:                     394.2
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           1.05e-20
# Time:                        22:40:29   Log-Likelihood:                 78.120
# No. Observations:                  30   AIC:                            -150.2
# Df Residuals:                      27   BIC:                            -146.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4346      0.591      0.736      0.468      -0.778       1.647
# ...

# %%
m9= statf.ols(formula = 'dem ~ Pol2 + dem1 +dem2', data = df).fit()
print(m9.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    dem   R-squared:                       0.967
# Model:                            OLS   Adj. R-squared:                  0.963
# Method:                 Least Squares   F-statistic:                     242.1
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           1.36e-18
# Time:                        22:40:36   Log-Likelihood:                 75.173
# No. Observations:                  29   AIC:                            -142.3
# Df Residuals:                      25   BIC:                            -136.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5196      0.634      0.820      0.420      -0.786       1.825
# ...

# %%
m10= statf.ols(formula = 'dem ~ CPI', data = df).fit()
print(m10.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    dem   R-squared:                       0.428
# Model:                            OLS   Adj. R-squared:                  0.409
# Method:                 Least Squares   F-statistic:                     21.74
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           6.48e-05
# Time:                        22:40:42   Log-Likelihood:                 36.858
# No. Observations:                  31   AIC:                            -69.72
# Df Residuals:                      29   BIC:                            -66.85
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.4542      0.365     17.666      0.000       5.707       7.201
# ...

# %%
m11= statf.ols(formula = 'dem ~ CPI +dem1', data = df).fit()
print(m11.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    dem   R-squared:                       0.962
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     340.0
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           7.18e-20
# Time:                        22:40:48   Log-Likelihood:                 75.979
# No. Observations:                  30   AIC:                            -146.0
# Df Residuals:                      27   BIC:                            -141.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5611      0.371     -1.511      0.142      -1.323       0.201
# ...

# %%
m11_1= statf.ols(formula = 'dem ~ CPI +dem1+dem2', data = df).fit()
print(m11_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    dem   R-squared:                       0.962
# Model:                            OLS   Adj. R-squared:                  0.957
# Method:                 Least Squares   F-statistic:                     210.8
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           7.18e-18
# Time:                        22:40:59   Log-Likelihood:                 73.242
# No. Observations:                  29   AIC:                            -138.5
# Df Residuals:                      25   BIC:                            -133.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.4020      0.444     -0.906      0.374      -1.316       0.512
# ...

# %%
m12= statf.ols(formula = 'dem ~ Govef', data = df).fit()
print(m12.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    dem   R-squared:                       0.442
# Model:                            OLS   Adj. R-squared:                  0.423
# Method:                 Least Squares   F-statistic:                     22.96
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           4.53e-05
# Time:                        22:41:05   Log-Likelihood:                 37.226
# No. Observations:                  31   AIC:                            -70.45
# Df Residuals:                      29   BIC:                            -67.58
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.4372      0.151     49.341      0.000       7.129       7.745
# ...

# %%
m13= statf.ols(formula = 'dem ~ Govef + dem1', data = df).fit()
print(m13.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    dem   R-squared:                       0.964
# Model:                            OLS   Adj. R-squared:                  0.961
# Method:                 Least Squares   F-statistic:                     359.8
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           3.44e-20
# Time:                        22:41:21   Log-Likelihood:                 76.797
# No. Observations:                  30   AIC:                            -147.6
# Df Residuals:                      27   BIC:                            -143.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.3177      0.412     -0.771      0.447      -1.163       0.528
# ...

# %%
m14= statf.ols(formula = 'dem ~ Govef + dem1 +dem2', data = df).fit()
print(m14.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    dem   R-squared:                       0.964
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                     224.8
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           3.32e-18
# Time:                        22:41:29   Log-Likelihood:                 74.139
# No. Observations:                  29   AIC:                            -140.3
# Df Residuals:                      25   BIC:                            -134.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1561      0.472     -0.331      0.744      -1.128       0.816
# ...

# %%
m15= statf.ols(formula = 'unequality ~ Govef', data = df).fit()
print(m15.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             unequality   R-squared:                       0.627
# Model:                            OLS   Adj. R-squared:                  0.615
# Method:                 Least Squares   F-statistic:                     48.83
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           1.11e-07
# Time:                        22:41:35   Log-Likelihood:                 76.112
# No. Observations:                  31   AIC:                            -148.2
# Df Residuals:                      29   BIC:                            -145.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3396      0.043      7.897      0.000       0.252       0.427
# ...

# %%
m16= statf.ols(formula = 'unequality ~ Govef +unequality1', data = df).fit()
print(m16.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             unequality   R-squared:                       0.945
# Model:                            OLS   Adj. R-squared:                  0.941
# Method:                 Least Squares   F-statistic:                     231.3
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           1.02e-17
# Time:                        22:41:41   Log-Likelihood:                 103.48
# No. Observations:                  30   AIC:                            -201.0
# Df Residuals:                      27   BIC:                            -196.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0729      0.029      2.515      0.018       0.013       0.132
# ...

# %%
m17= statf.ols(formula = 'unequality ~ Govef +unequality1 +unequality2', data = df).fit()
print(m17.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             unequality   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     125.4
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           3.42e-15
# Time:                        22:41:46   Log-Likelihood:                 99.705
# No. Observations:                  29   AIC:                            -191.4
# Df Residuals:                      25   BIC:                            -185.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0717      0.032      2.250      0.033       0.006       0.137
# ...

# %%
m18= statf.ols(formula = 'institbad ~ Govef', data = df).fit()
print(m18.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              institbad   R-squared:                       0.498
# Model:                            OLS   Adj. R-squared:                  0.481
# Method:                 Least Squares   F-statistic:                     28.78
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           9.20e-06
# Time:                        22:41:52   Log-Likelihood:                -95.367
# No. Observations:                  31   AIC:                             194.7
# Df Residuals:                      29   BIC:                             197.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     93.7481     10.858      8.634      0.000      71.541     115.955
# ...

# %%
m19= statf.ols(formula = 'institbad ~ Govef +institbad1', data = df).fit()
print(m19.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              institbad   R-squared:                       0.746
# Model:                            OLS   Adj. R-squared:                  0.727
# Method:                 Least Squares   F-statistic:                     39.56
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           9.45e-09
# Time:                        22:41:59   Log-Likelihood:                -81.433
# No. Observations:                  30   AIC:                             168.9
# Df Residuals:                      27   BIC:                             173.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     24.4868     16.407      1.492      0.147      -9.178      58.152
# ...

# %%
m20= statf.ols(formula = 'institbad ~ Govef +institbad1 +institbad2', data = df).fit()
print(m20.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              institbad   R-squared:                       0.733
# Model:                            OLS   Adj. R-squared:                  0.701
# Method:                 Least Squares   F-statistic:                     22.91
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           2.39e-07
# Time:                        22:42:05   Log-Likelihood:                -78.589
# No. Observations:                  29   AIC:                             165.2
# Df Residuals:                      25   BIC:                             170.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     30.5731     19.235      1.589      0.125      -9.042      70.189
# ...

# %%
m21= statf.ols(formula = 'dembad ~ Govef', data = df).fit()
print(m21.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 dembad   R-squared:                       0.412
# Model:                            OLS   Adj. R-squared:                  0.392
# Method:                 Least Squares   F-statistic:                     20.33
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           9.91e-05
# Time:                        22:42:10   Log-Likelihood:                -69.403
# No. Observations:                  31   AIC:                             142.8
# Df Residuals:                      29   BIC:                             145.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     33.4137      4.699      7.111      0.000      23.803      43.024
# ...

# %%
m21= statf.ols(formula = 'dembad ~ Govef +dembad1', data = df).fit()
print(m21.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 dembad   R-squared:                       0.885
# Model:                            OLS   Adj. R-squared:                  0.876
# Method:                 Least Squares   F-statistic:                     103.7
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           2.13e-13
# Time:                        22:42:16   Log-Likelihood:                -42.562
# No. Observations:                  30   AIC:                             91.12
# Df Residuals:                      27   BIC:                             95.33
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.4489      4.029      0.608      0.548      -5.818      10.716
# ...

# %%
m21= statf.ols(formula = 'dembad ~ Govef +dembad1 +dembad2', data = df).fit()
print(m21.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 dembad   R-squared:                       0.880
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     60.86
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           1.25e-11
# Time:                        22:42:21   Log-Likelihood:                -41.594
# No. Observations:                  29   AIC:                             91.19
# Df Residuals:                      25   BIC:                             96.66
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9872      4.724      0.421      0.678      -7.742      11.716
# ...

# %%
m22= statf.ols(formula = 'dembad ~ unequality', data = df).fit()
print(m22.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 dembad   R-squared:                       0.786
# Model:                            OLS   Adj. R-squared:                  0.779
# Method:                 Least Squares   F-statistic:                     106.5
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           3.23e-11
# Time:                        22:42:27   Log-Likelihood:                -53.745
# No. Observations:                  31   AIC:                             111.5
# Df Residuals:                      29   BIC:                             114.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      9.2027      0.394     23.331      0.000       8.396      10.009
# ...

# %%
m23= statf.ols(formula = 'dembad ~ unequality +dembad1', data = df).fit()
print(m23.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 dembad   R-squared:                       0.901
# Model:                            OLS   Adj. R-squared:                  0.893
# Method:                 Least Squares   F-statistic:                     122.6
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           2.84e-14
# Time:                        22:42:32   Log-Likelihood:                -40.327
# No. Observations:                  30   AIC:                             86.65
# Df Residuals:                      27   BIC:                             90.86
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.8706      1.136      2.526      0.018       0.539       5.202
# ...

# %%
m24= statf.ols(formula = 'dembad ~ unequality +dembad1 +dembad2', data = df).fit()
print(m24.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 dembad   R-squared:                       0.898
# Model:                            OLS   Adj. R-squared:                  0.886
# Method:                 Least Squares   F-statistic:                     73.19
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           1.63e-12
# Time:                        22:42:38   Log-Likelihood:                -39.216
# No. Observations:                  29   AIC:                             86.43
# Df Residuals:                      25   BIC:                             91.90
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.0992      1.220      2.540      0.018       0.586       5.612
# ...

# %%
m25= statf.ols(formula = 'institbad ~ unequality', data = df).fit()
print(m25.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              institbad   R-squared:                       0.618
# Model:                            OLS   Adj. R-squared:                  0.605
# Method:                 Least Squares   F-statistic:                     46.87
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           1.61e-07
# Time:                        22:43:00   Log-Likelihood:                -91.145
# No. Observations:                  31   AIC:                             186.3
# Df Residuals:                      29   BIC:                             189.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     28.8349      1.318     21.877      0.000      26.139      31.531
# ...

# %%
m26= statf.ols(formula = 'institbad ~ unequality +institbad1', data = df).fit()
print(m26.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              institbad   R-squared:                       0.781
# Model:                            OLS   Adj. R-squared:                  0.765
# Method:                 Least Squares   F-statistic:                     48.12
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           1.25e-09
# Time:                        22:43:06   Log-Likelihood:                -79.189
# No. Observations:                  30   AIC:                             164.4
# Df Residuals:                      27   BIC:                             168.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     11.4215      3.739      3.054      0.005       3.749      19.094
# ...

# %%
m27= statf.ols(formula = 'institbad ~ unequality +institbad1 +institbad2', data = df).fit()
print(m27.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              institbad   R-squared:                       0.776
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     28.88
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           2.75e-08
# Time:                        22:43:11   Log-Likelihood:                -76.055
# No. Observations:                  29   AIC:                             160.1
# Df Residuals:                      25   BIC:                             165.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     12.9960      3.962      3.280      0.003       4.836      21.156
# ...

# %%
m28= statf.ols(formula = 'rad ~ unequality', data = df).fit()
print(m28.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    rad   R-squared:                       0.620
# Model:                            OLS   Adj. R-squared:                  0.607
# Method:                 Least Squares   F-statistic:                     47.31
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           1.48e-07
# Time:                        22:43:16   Log-Likelihood:                -93.243
# No. Observations:                  31   AIC:                             190.5
# Df Residuals:                      29   BIC:                             193.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     24.0863      1.410     17.078      0.000      21.202      26.971
# ...

# %%
m28= statf.ols(formula = 'rad ~ unequality +rad1', data = df).fit()
print(m28.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    rad   R-squared:                       0.978
# Model:                            OLS   Adj. R-squared:                  0.977
# Method:                 Least Squares   F-statistic:                     607.3
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           3.59e-23
# Time:                        22:43:23   Log-Likelihood:                -47.159
# No. Observations:                  30   AIC:                             100.3
# Df Residuals:                      27   BIC:                             104.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.3835      1.107      1.250      0.222      -0.888       3.655
# ...

# %%
m29= statf.ols(formula = 'rad ~ unequality +rad1 +rad2', data = df).fit()
print(m29.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    rad   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     1122.
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           9.04e-27
# Time:                        22:43:28   Log-Likelihood:                -29.758
# No. Observations:                  29   AIC:                             67.52
# Df Residuals:                      25   BIC:                             72.99
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.6938      0.658      2.575      0.016       0.339       3.049
# ...

# %%
m30= statf.ols(formula = 'rad ~ dembad', data = df).fit()
print(m30.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    rad   R-squared:                       0.378
# Model:                            OLS   Adj. R-squared:                  0.356
# Method:                 Least Squares   F-statistic:                     17.61
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           0.000234
# Time:                        22:43:36   Log-Likelihood:                -100.89
# No. Observations:                  31   AIC:                             205.8
# Df Residuals:                      29   BIC:                             208.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     11.1903      4.978      2.248      0.032       1.008      21.372
# ...

# %%
m31= statf.ols(formula = 'rad ~ dembad +rad1', data = df).fit()
print(m31.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    rad   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                     755.7
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           1.99e-24
# Time:                        22:43:41   Log-Likelihood:                -43.945
# No. Observations:                  30   AIC:                             93.89
# Df Residuals:                      27   BIC:                             98.09
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.5572      0.975     -1.597      0.122      -3.557       0.443
# ...

# %%
m32= statf.ols(formula = 'rad ~ dembad +rad1 + rad2', data = df).fit()
print(m32.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    rad   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     1214.
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           3.42e-27
# Time:                        22:43:46   Log-Likelihood:                -28.632
# No. Observations:                  29   AIC:                             65.26
# Df Residuals:                      25   BIC:                             70.73
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1407      0.684     -0.206      0.839      -1.548       1.267
# ...

# %%
m33= statf.ols(formula = 'rad ~ institbad', data = df).fit()
print(m33.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    rad   R-squared:                       0.504
# Model:                            OLS   Adj. R-squared:                  0.486
# Method:                 Least Squares   F-statistic:                     29.42
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           7.82e-06
# Time:                        22:43:50   Log-Likelihood:                -97.385
# No. Observations:                  31   AIC:                             198.8
# Df Residuals:                      29   BIC:                             201.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.2903      5.123      0.837      0.409      -6.188      14.769
# ...

# %%
m34= statf.ols(formula = 'rad ~ institbad + rad1', data = df).fit()
print(m34.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    rad   R-squared:                       0.987
# Model:                            OLS   Adj. R-squared:                  0.986
# Method:                 Least Squares   F-statistic:                     1048.
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           2.56e-26
# Time:                        22:43:56   Log-Likelihood:                -39.111
# No. Observations:                  30   AIC:                             84.22
# Df Residuals:                      27   BIC:                             88.43
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.6640      0.899     -2.964      0.006      -4.508      -0.820
# ...

# %%
m35= statf.ols(formula = 'rad ~ institbad + rad1 + rad2', data = df).fit()
print(m35.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    rad   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     1150.
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           6.69e-27
# Time:                        22:44:01   Log-Likelihood:                -29.409
# No. Observations:                  29   AIC:                             66.82
# Df Residuals:                      25   BIC:                             72.29
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.7265      0.888     -0.818      0.421      -2.555       1.102
# ...

# %%
m36= statf.ols(formula = 'dem ~ rad', data = df).fit()
print(m36.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    dem   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.895
# Method:                 Least Squares   F-statistic:                     256.9
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           6.00e-16
# Time:                        22:44:07   Log-Likelihood:                 63.657
# No. Observations:                  31   AIC:                            -123.3
# Df Residuals:                      29   BIC:                            -120.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      8.5227      0.024    361.623      0.000       8.475       8.571
# ...

# %%
m37= statf.ols(formula = 'dem ~ rad + dem1', data = df).fit()
print(m37.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    dem   R-squared:                       0.970
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     443.0
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           2.28e-21
# Time:                        22:44:12   Log-Likelihood:                 79.814
# No. Observations:                  30   AIC:                            -153.6
# Df Residuals:                      27   BIC:                            -149.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.7471      0.867      2.015      0.054      -0.032       3.526
# ...

# %%
m38= statf.ols(formula = 'dem ~ rad + dem1 +dem2', data = df).fit()
print(m38.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    dem   R-squared:                       0.971
# Model:                            OLS   Adj. R-squared:                  0.967
# Method:                 Least Squares   F-statistic:                     274.9
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           2.92e-19
# Time:                        22:44:18   Log-Likelihood:                 76.962
# No. Observations:                  29   AIC:                            -145.9
# Df Residuals:                      25   BIC:                            -140.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9209      0.924      2.078      0.048       0.017       3.825
# ...

# %%
m39= statf.ols(formula = 'dem ~ CPI + Pol2 + Govef + unequality + institbad + dembad + rad + violence', data = df).fit()
print(m39.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    dem   R-squared:                       0.970
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     88.99
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           5.88e-15
# Time:                        22:44:24   Log-Likelihood:                 82.551
# No. Observations:                  31   AIC:                            -147.1
# Df Residuals:                      22   BIC:                            -134.2
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      8.0260      0.204     39.332      0.000       7.603       8.449
# ...

# %%
m40= statf.ols(formula = 'dem ~ CPI + Pol2 + Govef + unequality + institbad + dembad + rad + violence + dem1', data = df).fit()
print(m40.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    dem   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                     106.3
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           6.63e-15
# Time:                        22:44:29   Log-Likelihood:                 85.329
# No. Observations:                  30   AIC:                            -150.7
# Df Residuals:                      20   BIC:                            -136.6
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.4553      1.310      3.400      0.003       1.722       7.188
# ...

# %%
m41= statf.ols(formula = 'dem ~ CPI + Pol2 + Govef + unequality + institbad + dembad + rad + violence + dem1 +dem2', data = df).fit()
print(m41.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    dem   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.972
# Method:                 Least Squares   F-statistic:                     97.46
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           1.42e-13
# Time:                        22:44:35   Log-Likelihood:                 83.978
# No. Observations:                  29   AIC:                            -146.0
# Df Residuals:                      18   BIC:                            -130.9
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.0944      1.349      3.775      0.001       2.259       7.929
# ...

# %%
m42= statf.ols(formula = 'violence ~ dem + violence1', data = df).fit()
print(m42.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               violence   R-squared:                       0.664
# Model:                            OLS   Adj. R-squared:                  0.640
# Method:                 Least Squares   F-statistic:                     26.73
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           3.97e-07
# Time:                        22:44:41   Log-Likelihood:                 35.762
# No. Observations:                  30   AIC:                            -65.52
# Df Residuals:                      27   BIC:                            -61.32
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.9555      1.177     -1.661      0.108      -4.371       0.460
# ...

# %%
m43= statf.ols(formula = 'rad ~ Pol2', data = df).fit()
print(m43.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    rad   R-squared:                       0.721
# Model:                            OLS   Adj. R-squared:                  0.711
# Method:                 Least Squares   F-statistic:                     74.78
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           1.60e-09
# Time:                        22:44:46   Log-Likelihood:                -88.477
# No. Observations:                  31   AIC:                             181.0
# Df Residuals:                      29   BIC:                             183.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      9.5157      2.659      3.578      0.001       4.077      14.954
# ...

# %%
m44= statf.ols(formula = 'rad ~ Pol2 + rad1', data = df).fit()
print(m44.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    rad   R-squared:                       0.978
# Model:                            OLS   Adj. R-squared:                  0.976
# Method:                 Least Squares   F-statistic:                     599.7
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           4.24e-23
# Time:                        22:44:53   Log-Likelihood:                -47.345
# No. Observations:                  30   AIC:                             100.7
# Df Residuals:                      27   BIC:                             104.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1139      0.943      0.121      0.905      -1.821       2.049
# ...

# %%
m45= statf.ols(formula = 'rad ~ Pol2 + rad1 + rad2', data = df).fit()
print(m45.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    rad   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     1208.
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           3.63e-27
# Time:                        22:45:00   Log-Likelihood:                -28.700
# No. Observations:                  29   AIC:                             65.40
# Df Residuals:                      25   BIC:                             70.87
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.8527      0.562      1.516      0.142      -0.306       2.011
# ...

# %%
m46= statf.ols(formula = 'violence ~ Pol2 + violence1 +violence2', data = df).fit()
print(m46.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               violence   R-squared:                       0.628
# Model:                            OLS   Adj. R-squared:                  0.583
# Method:                 Least Squares   F-statistic:                     14.06
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           1.43e-05
# Time:                        22:45:06   Log-Likelihood:                 32.591
# No. Observations:                  29   AIC:                            -57.18
# Df Residuals:                      25   BIC:                            -51.71
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2686      0.164      1.636      0.114      -0.070       0.607
# ...

# %%
m47= statf.ols(formula = 'rad ~ CPI + rad1 + rad2', data = df).fit()
print(m47.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    rad   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     1220.
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           3.21e-27
# Time:                        22:45:11   Log-Likelihood:                -28.558
# No. Observations:                  29   AIC:                             65.12
# Df Residuals:                      25   BIC:                             70.58
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     14.0450      4.607      3.049      0.005       4.557      23.533
# ...

# %%
m48= statf.ols(formula = 'violence ~ Pol2 + violence1 + violence2', data = df).fit()
print(m48.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               violence   R-squared:                       0.628
# Model:                            OLS   Adj. R-squared:                  0.583
# Method:                 Least Squares   F-statistic:                     14.06
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           1.43e-05
# Time:                        22:45:17   Log-Likelihood:                 32.591
# No. Observations:                  29   AIC:                            -57.18
# Df Residuals:                      25   BIC:                            -51.71
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2686      0.164      1.636      0.114      -0.070       0.607
# ...

# %%
m49= statf.ols(formula = 'violence ~ CPI + violence1 + violence2', data = df).fit()
print(m49.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               violence   R-squared:                       0.629
# Model:                            OLS   Adj. R-squared:                  0.585
# Method:                 Least Squares   F-statistic:                     14.13
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           1.38e-05
# Time:                        22:45:25   Log-Likelihood:                 32.634
# No. Observations:                  29   AIC:                            -57.27
# Df Residuals:                      25   BIC:                            -51.80
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4440      0.462      0.961      0.346      -0.508       1.396
# ...

# %%
m50= statf.ols(formula = 'unequality ~ Pol2 + unequality1 + unequality2', data = df).fit()
print(m50.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             unequality   R-squared:                       0.935
# Model:                            OLS   Adj. R-squared:                  0.927
# Method:                 Least Squares   F-statistic:                     119.9
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           5.76e-15
# Time:                        22:45:31   Log-Likelihood:                 99.099
# No. Observations:                  29   AIC:                            -190.2
# Df Residuals:                      25   BIC:                            -184.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -0.0103      0.010     -0.993      0.330      -0.032       0.011
# ...

# %%
m51= statf.ols(formula = 'dembad ~ Pol2 + dembad1 + dembad2', data = df).fit()
print(m51.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 dembad   R-squared:                       0.890
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     67.45
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           4.03e-12
# Time:                        22:45:35   Log-Likelihood:                -40.274
# No. Observations:                  29   AIC:                             88.55
# Df Residuals:                      25   BIC:                             94.02
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.2147      0.833      1.458      0.157      -0.501       2.931
# ...

# %%
m52= statf.ols(formula = 'institbad ~ Pol2 + institbad1 + institbad2', data = df).fit()
print(m52.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              institbad   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.725
# Method:                 Least Squares   F-statistic:                     25.59
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           8.64e-08
# Time:                        22:45:41   Log-Likelihood:                -77.396
# No. Observations:                  29   AIC:                             162.8
# Df Residuals:                      25   BIC:                             168.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      9.3284      3.646      2.558      0.017       1.819      16.838
# ...

# %%
m52_2= statf.ols(formula = 'rad ~ Govef + rad1 + rad2', data = df).fit() 
print(m52_2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              institbad   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.725
# Method:                 Least Squares   F-statistic:                     25.59
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           8.64e-08
# Time:                        22:45:54   Log-Likelihood:                -77.396
# No. Observations:                  29   AIC:                             162.8
# Df Residuals:                      25   BIC:                             168.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      9.3284      3.646      2.558      0.017       1.819      16.838
# ...

# %%
m53= statf.ols(formula = 'violence ~ Govef + violence1 + violence2', data = df).fit()
print(m53.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               violence   R-squared:                       0.630
# Model:                            OLS   Adj. R-squared:                  0.586
# Method:                 Least Squares   F-statistic:                     14.22
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           1.31e-05
# Time:                        22:46:02   Log-Likelihood:                 32.690
# No. Observations:                  29   AIC:                            -57.38
# Df Residuals:                      25   BIC:                            -51.91
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1367      0.282      0.485      0.632      -0.443       0.717
# ...
